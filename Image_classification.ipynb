# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/bettygetachew56/myenv/lib/python3.11/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Function to load images from a given folder
def load_images_from_folder(folder, label, img_size=(256, 256)):
    images = []
    labels = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = cv2.resize(img, img_size)
            images.append(img)
            labels.append(label)
    return np.array(images), np.array(labels)

# Load cat and dog images
cats, cat_labels = load_images_from_folder('dataset/train/cat', label=0)
dogs, dog_labels = load_images_from_folder('dataset/train/dog', label=1)

# %%
# Combine the datasets
X = np.concatenate((cats, dogs), axis=0)
y = np.concatenate((cat_labels, dog_labels), axis=0)

# %%
# Flatten the images for SVM input
X_flattened = X.reshape(X.shape[0], -1)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_flattened, y, test_size=0.2, random_state=42)

# %%
# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Train the model
from sklearn.svm import SVC

# Train the SVM model with a linear kernel
svm = SVC(kernel='rbf', C=1.0, verbose=True, random_state=42)
svm.fit(X_train, y_train)
# Out:
# [LibSVM]..*
# optimization finished, #iter = 2959
# obj = -1976.760898, rho = 0.266156
# nSV = 2965, nBSV = 2153
# Total nSV = 2965
# SVC(random_state=42, verbose=True)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Make predictions
y_pred = svm.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', cm)

# Classification report
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.63
# Confusion Matrix:
#  [[233 189]
#  [106 273]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.55      0.61       422
#            1       0.59      0.72      0.65       379
#
#     accuracy                           0.63       801
#    macro avg       0.64      0.64      0.63       801
# weighted avg       0.64      0.63      0.63       801

# %%
# improve the  model
svm = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)
svm.fit(X_train, y_train)
# Out:
# SVC(random_state=42)

# %%
import joblib

# Save the trained model to a file
model_filename = 'svm_cats_dogs_model.pkl'
joblib.dump(svm, model_filename)

print(f"Model saved to {model_filename}")
# Out:
# Model saved to svm_cats_dogs_model.pkl

# %%
# Load the model from the file
loaded_model = joblib.load(model_filename)

print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
# Example test on new data (you can load new images or use the test set)
y_pred = loaded_model.predict(X_test)

# Evaluate the model's performance on the test set
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy on test set: {accuracy:.2f}')

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', cm)

# Classification report
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Accuracy on test set: 0.63
# Confusion Matrix:
#  [[233 189]
#  [106 273]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.55      0.61       422
#            1       0.59      0.72      0.65       379
#
#     accuracy                           0.63       801
#    macro avg       0.64      0.64      0.63       801
# weighted avg       0.64      0.63      0.63       801

# %%
def preprocess_image(image_path, img_size=(256, 256)):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, img_size)
    img = img.flatten()  # Flatten the image to match the model's input shape
    img = scaler.transform([img])  # Apply the same scaler used in training
    return img

# Load and preprocess a new image
new_image_path = 'dataset/test1/2010.jpg'  # Replace with the path to the new image
new_image = preprocess_image(new_image_path)

# Predict the class
prediction = loaded_model.predict(new_image)
print(f'Predicted class: {"Cat" if prediction[0] == 0 else "Dog"}')
# Out:
# Predicted class: Dog

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in /home/bettygetachew56/myenv/lib/python3.11/site-packages (4.42.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (4.3.0)
# Requirement already satisfied: fastapi in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.112.2)
# Requirement already satisfied: ffmpy in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.3.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.21.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (6.4.4)
# Requirement already satisfied: jinja2<4.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (3.9.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (3.9.15)
# Requirement already satisfied: packaging in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (2.2.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (10.2.0)
# Requirement already satisfied: pydantic>=2.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (2.6.3)
# Requirement already satisfied: pydub in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.6.2)
# Requirement already satisfied: semantic-version~=2.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (4.10.0)
# Requirement already satisfied: urllib3~=2.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (2.2.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio) (0.30.6)
# Requirement already satisfied: fsspec in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio-client==1.3.0->gradio) (2024.2.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from pydantic>=2.0->gradio) (2.16.3)
# Requirement already satisfied: click>=8.0.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from fastapi->gradio) (0.38.2)
# Requirement already satisfied: six>=1.5 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in /home/bettygetachew56/myenv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr
import cv2
import numpy as np

def classify_image(image):
    # Resize the image to 256x256
    img_resized = cv2.resize(image, (256, 256))
    
    # Convert the image to grayscale if necessary
    img_gray = cv2.cvtColor(img_resized, cv2.COLOR_BGR2GRAY)
    
    # Flatten the image
    img_flattened = img_gray.flatten().reshape(1, -1)
    
    # Apply the same standardization used during training
    img_scaled = scaler.transform(img_flattened)
    
    # Make a prediction using the trained SVM model
    prediction = svm.predict(img_scaled)
    
    return "Cat" if prediction == 0 else "Dog"

interface = gr.Interface(
    fn=classify_image,
    inputs=gr.Image(),  # Define the input as an image
    outputs="text",  # Define the output as text
    title="Cat vs Dog Classifier",
)

interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
